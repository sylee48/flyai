# %%
# !pip install --upgrade --user seaborn -q

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.__version__
# Out:
# '0.12.1'

# %%
df = sns.load_dataset('penguins')
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# ### Axes Level

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species')
plt.show()

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data=df, x='species', hue='species')
# Out:
# <AxesSubplot: xlabel='species', ylabel='Count'>

# %%
fig, axes = plt.subplots(2, 2, figsize=(10, 10))
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axes[0, 0])
sns.histplot(data=df, x='flipper_length_mm', hue='species', ax=axes[1, 0])
sns.scatterplot(data=df, x='flipper_length_mm', y='bill_length_mm', hue='species', ax=axes[1, 1])
sns.histplot(data=df, x='flipper_length_mm', hue='species', ax=axes[0, 1])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Figure-Level

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
sns.displot(data=df, x='flipper_length_mm', kind='hist', hue='species')

# %%
sns.displot(data=df, x='flipper_length_mm', kind='hist', hue='species', col='species')

# %%
sns.displot(data=df, x='flipper_length_mm', kind='kde', hue='species', col='species')

# %%
sns.displot(data=df, x='flipper_length_mm', kind='ecdf', hue='species', col='species')

# %%
sns.relplot(data=df, x='flipper_length_mm', y='bill_length_mm', kind='scatter', hue='species', col='species')

# %%
sns.relplot(data=df, x='flipper_length_mm', y='bill_length_mm', kind='line', hue='species', col='species')

# %%
sns.relplot(data=df, x='flipper_length_mm', y='bill_length_mm', kind='scatter', hue='species', height=5, aspect=2)

# %%
import pandas as pd

pd.__version__
# Out:
# '1.5.2'

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId Survived Pclass  \
# 0              1     lost    3rd
# 1              2    saved    1st
# 2              3    saved    3rd
# 3              4    saved    1st
# 4              5     lost    3rd
# ..           ...      ...    ...
# 886          887     lost    2nd
# 887          888    saved    1st
# 888          889     lost    3rd
# 889          890    saved    1st
# 890          891     lost    3rd
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.barplot(data=df, x='Pclass', y='Fare')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Fare'>

# %%
sns.countplot(data=df, x='Pclass')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='count'>

# %%
df['Pclass'].value_counts()
# Out:
# 3rd    491
# 1st    216
# 2nd    184
# Name: Pclass, dtype: int64

# %%
sns.barplot(data=df, x='Pclass', y='Fare', hue='Sex', estimator=np.mean)
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(data=df, x='Pclass', y='Age')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %%
sns.violinplot(data=df, x='Pclass', y='Age')
# Out:
# <AxesSubplot: xlabel='Pclass', ylabel='Age'>

# %%
import numpy as np
data = np.random.rand(3, 3)
data
# Out:
# array([[0.9647589 , 0.96807941, 0.85298853],
#        [0.43211256, 0.7331536 , 0.17309427],
#        [0.28180604, 0.89498736, 0.99435932]])

# %%
sns.heatmap(data, annot=True, cmap='mako')
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1     lost    3rd
# 1            2    saved    1st
# 2            3    saved    3rd
# 3            4    saved    1st
# 4            5     lost    3rd
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv('iris.csv',index_col=0)
df.shape
# Out:
# (150, 5)

# %%
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='Species')

# %%
! gdown https://raw.githubusercontent.com/devdio/datasets/main/tips.csv -q

# %%
df = pd.read_csv('tips.csv')
df.shape
# Out:
# (244, 7)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(data=df, x='day')
# Out:
# <AxesSubplot: xlabel='day', ylabel='count'>

# %%
sns.barplot(data=df, x='smoker', y='tip', hue='sex', estimator=np.mean)
# Out:
# <AxesSubplot: xlabel='smoker', ylabel='tip'>

# %%
sns.barplot(data=df, x='day', y='tip', hue='sex', estimator=np.mean)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.pairplot(df, hue='time')

# %%
sns.barplot(data=df, x='day', y='tip', hue='time', estimator=np.sum)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=df, x='day', y='total_bill', hue='time', estimator=np.sum)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=df, x='day', y='tip', hue='sex', estimator=np.sum)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>

# %%
sns.barplot(data=df, x='day', y='tip', hue='smoker', estimator=np.sum)
# Out:
# <AxesSubplot: xlabel='day', ylabel='tip'>
